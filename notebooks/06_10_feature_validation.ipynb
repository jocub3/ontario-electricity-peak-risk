# %% [markdown]
# # 06.10 — Feature Validation
#
# Confirm row preservation, key uniqueness, lag alignment, finite values, and rolling-history rules.

# %%
# Import libraries
from pathlib import Path
import pandas as pd

# %%
# Define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists(): PROJECT_ROOT = PROJECT_ROOT.parent
REPORTS_DIR = PROJECT_ROOT / 'reports' / 'feature_engineering'
REPORTS_DIR
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/reports/feature_engineering')

# %%
# Load the feature validation report
validation = pd.read_csv(REPORTS_DIR / '06_05_feature_validation.csv')
validation
# Out:
#                                                 check  violations status  \
# 0                                 row_count_preserved           0   PASS
# 1                                          unique_key           0   PASS
# 2                                        key_not_null           0   PASS
# 3                                  no_infinite_values           0   PASS
# 4                                    lag_1h_alignment           0   PASS
# 5   rolling_history_required::total_consumption_kw...           0   PASS
# 6   rolling_history_required::total_consumption_kw...           0   PASS
# 7   rolling_history_required::total_consumption_kw...           0   PASS
# 8   rolling_history_required::total_consumption_kw...           0   PASS
# 9   rolling_history_required::total_consumption_kw...           0   PASS
# 10  rolling_history_required::total_consumption_kw...           0   PASS
# 11  rolling_history_required::total_consumption_kw...           0   PASS
# ...

# %%
# Check if all feature validation checks passed
assert (validation['status'] == 'PASS').all(), 'One or more feature validation checks failed.'
print('All feature validation checks passed.')
# Out:
# All feature validation checks passed.
