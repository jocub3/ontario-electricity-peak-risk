# %% [markdown]
# # 06.00 — Feature Engineering Design
#
# Review the planned feature families and leakage policy before creating variables.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / 'configs' / 'feature_engineering.yaml'
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/configs/feature_engineering.yaml')

# %%
# Import module to manage the Feature Engineering process
from src.ontario_peak_risk.feature_engineering.common import (
    load_feature_config,
    load_clean_dataset,
    ensure_directories,
)

# %%
# Config Feature Engineering process and Load the dataset
CONFIG, _ = load_feature_config(CONFIG_PATH)
REPORTS_DIR, DOCS_DIR = ensure_directories(CONFIG, PROJECT_ROOT)
clean_dataset = load_clean_dataset(CONFIG, PROJECT_ROOT)
clean_dataset.shape
# Out:
# (262944, 66)

# %%
# Load the Feature Engineering configuration file
with CONFIG_PATH.open('r', encoding='utf-8') as file:
    feature_config = yaml.safe_load(file)
feature_config
# Out:
# {'paths': {'input_clean_dataset': 'data/processed/master_dataset_clean.parquet',
#   'base_dataset': 'data/interim/feature_dataset_base.parquet',
#   'final_dataset': 'data/processed/feature_dataset.parquet',
#   'reports_dir': 'reports/feature_engineering',
#   'docs_dir': 'docs/feature_engineering'},
#  'feature_engineering': {'key_columns': ['fsa', 'timestamp'],
#   'target_column': 'total_consumption_kwh',
#   'traceability_columns': ['timestamp',
#    'timestamp_utc',
#    'timestamp_toronto',
#    'date',
#    'assigned_climate_id',
#    'assigned_station_name',
#    'Longitude (x)',
#    'Latitude (y)',
#    'Climate ID'],
#   'baseline_drop_columns': ['month_name', 'weekday_name'],
#   'temporal': {'use_existing_calendar_fields': True,
#    'create_cyclical_features': True,
#    'cyclical_features': {'hour': {'period': 24},
#     'weekday': {'period': 7},
#     'month': {'period': 12},
#     'day_of_year': {'period': 365.25}}},
#   'lags': {'target_lags_hours': [1, 2, 3, 24, 48, 168]},
#   'rolling': {'target_windows_hours': [3, 6, 24, 168],
#    'statistics': ['mean', 'std', 'min', 'max']},
#   'weather': {'temperature_column': 'Temp (°C)',
#    'humidity_column': 'Rel Hum (%)',
#    'pressure_column': 'Stn Press (kPa)',
#    'temperature_difference_lags': [1, 24],
#    'humidity_difference_lags': [1],
#    'pressure_difference_lags': [1],
#    'weather_rolling_windows': [6, 24],
#    'heating_base_c': 18.0,
#    'cooling_base_c': 18.0},
#   'interactions': {'create_temperature_hour': True,
#    'create_temperature_weekend': True,
#    'create_temperature_season': False,
#    'create_fsa_season': False},
#   'peak': {'create_training_window_peak_features': False},
#   'selection': {'high_missingness_threshold_pct': 80.0,
#    'medium_missingness_threshold_pct': 50.0,
#    'correlation_redundancy_threshold': 0.95,
#    'vif_threshold': 10.0},
#   'validation': {'require_unique_key': True,
#    'reject_infinite_values': True,
#    'allow_expected_lag_nans': True}}}
