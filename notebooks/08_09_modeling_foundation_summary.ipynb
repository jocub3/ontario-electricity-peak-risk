# %% [markdown]
# # 08.09 — Modeling Foundation Summary
#
# Execute the complete framework workflow and inspect the formal handoff to future model branches.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "modeling_foundation.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/modeling_foundation.yaml')

# %%
# Import module to manage modeling configuration, feature datasets, and directories
from src.ontario_peak_risk.modeling.common import (
    load_modeling_config,
    load_feature_dataset,
    ensure_modeling_directories,
)

# %%
# Load the modeling configuration, feature dataset, and ensure necessary directories exist
CONFIG, _ = load_modeling_config(CONFIG_PATH)
REPORTS_DIR, DOCS_DIR, OUTPUTS_DIR = ensure_modeling_directories(CONFIG, PROJECT_ROOT)
feature_dataset = load_feature_dataset(CONFIG, PROJECT_ROOT)
feature_dataset.shape
# Out:
# (262944, 100)

# %%
# Import the run_modeling_foundation function
from src.ontario_peak_risk.modeling.run_modeling_foundation import run_modeling_foundation

# %%
# Run the modeling foundation function and store the results
results = run_modeling_foundation(CONFIG_PATH)
results.keys()
# Out:
# Modeling Foundation Phase completed successfully.
# Feature rows: 262,944
# Complete Forecasting target rows: 262,800
# Maximum forecast horizon: 24 hours
# Forecasting selection metric: mae
# Peak-Risk selection metric: pr_auc
# Initial classification threshold: 0.5
# Validation folds: 2
# Final holdout: test_2025
# Reports: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\reports\modeling_foundation
# Documentation: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\docs\modeling_foundation
# dict_keys(['feature_dataset', 'forecast_targets', 'validation_folds', 'final_holdout', 'split_summary', 'fsa_coverage', 'metric_dictionary', 'peak_horizon_policy', 'framework_validation', 'outputs_dir'])

# %%
# Display the split summary from the results
results["split_summary"]
# Out:
#         fold        role configured_train_start configured_train_end  \
# 0  fold_2023  validation             2021-01-01  2022-12-31 23:00:00
# 1  fold_2024  validation             2021-01-01  2023-12-31 23:00:00
# 2  test_2025        test             2021-01-01  2024-12-31 23:00:00
#
#   safe_train_origin_end  train_rows train_first_origin   train_last_origin  \
# 0   2022-12-30 23:00:00      104976         2021-01-01 2022-12-30 23:00:00
# 1   2023-12-30 23:00:00      157536         2021-01-01 2023-12-30 23:00:00
# 2   2024-12-30 23:00:00      210240         2021-01-01 2024-12-30 23:00:00
#
#    train_fsas configured_evaluation_start configured_evaluation_end  \
# 0           6                  2023-01-01       2023-12-31 23:00:00
# 1           6                  2024-01-01       2024-12-31 23:00:00
# 2           6                  2025-01-01       2025-12-31 23:00:00
#
#   safe_evaluation_origin_end  evaluation_rows evaluation_first_origin  \
# 0        2023-12-30 23:00:00            52416              2023-01-01
# 1        2024-12-30 23:00:00            52560              2024-01-01
# 2        2025-12-30 23:00:00            52416              2025-01-01
#
#   evaluation_last_origin  evaluation_fsas  max_horizon_hours
# 0    2023-12-30 23:00:00                6                 24
# 1    2024-12-30 23:00:00                6                 24
# 2    2025-12-30 23:00:00                6                 24

# %%
# Display the metric dictionary from the results
results["metric_dictionary"]
# Out:
#            task             metric       role         direction  \
# 0   forecasting                MAE    primary   lower_is_better
# 1   forecasting               RMSE    primary   lower_is_better
# 2   forecasting               MAPE    primary   lower_is_better
# 3   forecasting               WAPE  secondary   lower_is_better
# 4   forecasting               Bias  secondary    closer_to_zero
# 5     peak_risk          Precision    primary  higher_is_better
# 6     peak_risk             Recall    primary  higher_is_better
# 7     peak_risk                 F1    primary  higher_is_better
# 8     peak_risk             PR-AUC    primary  higher_is_better
# 9     peak_risk            ROC-AUC  secondary  higher_is_better
# 10    peak_risk  Balanced Accuracy  secondary  higher_is_better
#
#                                           description
# 0                Mean absolute forecast error in kWh.
# 1            Root mean squared forecast error in kWh.
# 2   Mean absolute percentage error for non-zero de...
# 3   Absolute error relative to total observed demand.
# 4                         Mean signed forecast error.
# 5       Share of predicted Peaks that are true Peaks.
# 6             Share of true Peaks correctly detected.
# 7              Harmonic mean of Precision and Recall.
# 8   Precision-Recall area; emphasized for class im...
# 9                           Area under the ROC curve.
# 10                Average recall across both classes.

# %%
# Display the framework validation results from the results
results["framework_validation"]
# Out:
#          fold             role                                       check  \
# 0   fold_2023       validation                             non_empty_train
# 1   fold_2023       validation                        non_empty_evaluation
# 2   fold_2023       validation                   train_precedes_evaluation
# 3   fold_2023       validation                           same_fsa_coverage
# 4   fold_2023       validation                         no_temporal_overlap
# 5   fold_2023       validation                train_origin_is_horizon_safe
# 6   fold_2023       validation           evaluation_origin_is_horizon_safe
# 7   fold_2024       validation                             non_empty_train
# 8   fold_2024       validation                        non_empty_evaluation
# 9   fold_2024       validation                   train_precedes_evaluation
# 10  fold_2024       validation                           same_fsa_coverage
# 11  fold_2024       validation                         no_temporal_overlap
# 12  fold_2024       validation                train_origin_is_horizon_safe
# 13  fold_2024       validation           evaluation_origin_is_horizon_safe
# 14  test_2025             test                             non_empty_train
# 15  test_2025             test                        non_empty_evaluation
# 16  test_2025             test                   train_precedes_evaluation
# 17  test_2025             test                           same_fsa_coverage
# 18  test_2025             test                         no_temporal_overlap
# 19  test_2025             test                train_origin_is_horizon_safe
# 20  test_2025             test           evaluation_origin_is_horizon_safe
# 21     global  forecast_target    all_forecasting_target_columns_available
# 22  fold_2023       validation                      train_horizon_complete
# 23  fold_2023       validation                 evaluation_horizon_complete
# 24  fold_2023       validation            train_h24_within_training_period
# 25  fold_2023       validation     evaluation_h24_within_evaluation_period
# 26  fold_2024       validation                      train_horizon_complete
# 27  fold_2024       validation                 evaluation_horizon_complete
# 28  fold_2024       validation            train_h24_within_training_period
# 29  fold_2024       validation     evaluation_h24_within_evaluation_period
# 30  test_2025             test                      train_horizon_complete
# 31  test_2025             test                 evaluation_horizon_complete
# 32  test_2025             test            train_h24_within_training_period
# 33  test_2025             test     evaluation_h24_within_evaluation_period
# 34        NaN              NaN  final_holdout_after_all_validation_periods
# 35        NaN              NaN       preprocessing_fit_scope_training_only
# 36        NaN              NaN     forecasting_selection_metric_is_primary
# 37        NaN              NaN            peak_selection_metric_is_primary
# 38        NaN              NaN  classification_probability_threshold_valid
# 39        NaN              NaN            forecast_and_peak_horizons_match
#
#    status details latest_validation_end test_start configured_value
# 0    PASS     NaN                   NaT        NaT              NaN
# 1    PASS     NaN                   NaT        NaT              NaN
# 2    PASS     NaN                   NaT        NaT              NaN
# 3    PASS     NaN                   NaT        NaT              NaN
# 4    PASS     NaN                   NaT        NaT              NaN
# 5    PASS     NaN                   NaT        NaT              NaN
# 6    PASS     NaN                   NaT        NaT              NaN
# 7    PASS     NaN                   NaT        NaT              NaN
# 8    PASS     NaN                   NaT        NaT              NaN
# 9    PASS     NaN                   NaT        NaT              NaN
# 10   PASS     NaN                   NaT        NaT              NaN
# 11   PASS     NaN                   NaT        NaT              NaN
# 12   PASS     NaN                   NaT        NaT              NaN
# 13   PASS     NaN                   NaT        NaT              NaN
# 14   PASS     NaN                   NaT        NaT              NaN
# 15   PASS     NaN                   NaT        NaT              NaN
# 16   PASS     NaN                   NaT        NaT              NaN
# 17   PASS     NaN                   NaT        NaT              NaN
# 18   PASS     NaN                   NaT        NaT              NaN
# 19   PASS     NaN                   NaT        NaT              NaN
# 20   PASS     NaN                   NaT        NaT              NaN
# 21   PASS                           NaT        NaT              NaN
# 22   PASS                           NaT        NaT              NaN
# 23   PASS                           NaT        NaT              NaN
# 24   PASS                           NaT        NaT              NaN
# 25   PASS                           NaT        NaT              NaN
# 26   PASS                           NaT        NaT              NaN
# 27   PASS                           NaT        NaT              NaN
# 28   PASS                           NaT        NaT              NaN
# 29   PASS                           NaT        NaT              NaN
# 30   PASS                           NaT        NaT              NaN
# 31   PASS                           NaT        NaT              NaN
# 32   PASS                           NaT        NaT              NaN
# 33   PASS                           NaT        NaT              NaN
# 34   PASS     NaN   2024-12-31 23:00:00 2025-01-01              NaN
# 35   PASS     NaN                   NaT        NaT    training_only
# 36   PASS     NaN                   NaT        NaT              NaN
# 37   PASS     NaN                   NaT        NaT              NaN
# 38   PASS     NaN                   NaT        NaT              NaN
# 39   PASS     NaN                   NaT        NaT              NaN

# %%
# Review FSA coverage
results["fsa_coverage"]
# Out:
#          fold        role  fsa  train_rows  evaluation_rows status
# 0   fold_2023  validation  L4T       17496             8736   PASS
# 1   fold_2023  validation  M5R       17496             8736   PASS
# 2   fold_2023  validation  M5S       17496             8736   PASS
# 3   fold_2023  validation  M6G       17496             8736   PASS
# 4   fold_2023  validation  M9R       17496             8736   PASS
# 5   fold_2023  validation  M9W       17496             8736   PASS
# 6   fold_2024  validation  L4T       26256             8760   PASS
# 7   fold_2024  validation  M5R       26256             8760   PASS
# 8   fold_2024  validation  M5S       26256             8760   PASS
# 9   fold_2024  validation  M6G       26256             8760   PASS
# 10  fold_2024  validation  M9R       26256             8760   PASS
# 11  fold_2024  validation  M9W       26256             8760   PASS
# 12  test_2025        test  L4T       35040             8736   PASS
# 13  test_2025        test  M5R       35040             8736   PASS
# 14  test_2025        test  M5S       35040             8736   PASS
# 15  test_2025        test  M6G       35040             8736   PASS
# 16  test_2025        test  M9R       35040             8736   PASS
# 17  test_2025        test  M9W       35040             8736   PASS

# %%
# Review Peak-Risk multi-horizon policy
results["peak_horizon_policy"]
# Out:
#     horizon    target  target_offset_hours  \
# 0         1  peak_h01                    1
# 1         2  peak_h02                    2
# 2         3  peak_h03                    3
# 3         4  peak_h04                    4
# 4         5  peak_h05                    5
# 5         6  peak_h06                    6
# 6         7  peak_h07                    7
# 7         8  peak_h08                    8
# 8         9  peak_h09                    9
# 9        10  peak_h10                   10
# 10       11  peak_h11                   11
# 11       12  peak_h12                   12
# 12       13  peak_h13                   13
# 13       14  peak_h14                   14
# 14       15  peak_h15                   15
# 15       16  peak_h16                   16
# 16       17  peak_h17                   17
# 17       18  peak_h18                   18
# 18       19  peak_h19                   19
# 19       20  peak_h20                   20
# 20       21  peak_h21                   21
# 21       22  peak_h22                   22
# 22       23  peak_h23                   23
# 23       24  peak_h24                   24
#
#                                            definition  \
# 0   Peak status of the corresponding FSA at foreca...
# 1   Peak status of the corresponding FSA at foreca...
# 2   Peak status of the corresponding FSA at foreca...
# 3   Peak status of the corresponding FSA at foreca...
# 4   Peak status of the corresponding FSA at foreca...
# 5   Peak status of the corresponding FSA at foreca...
# 6   Peak status of the corresponding FSA at foreca...
# 7   Peak status of the corresponding FSA at foreca...
# 8   Peak status of the corresponding FSA at foreca...
# 9   Peak status of the corresponding FSA at foreca...
# 10  Peak status of the corresponding FSA at foreca...
# 11  Peak status of the corresponding FSA at foreca...
# 12  Peak status of the corresponding FSA at foreca...
# 13  Peak status of the corresponding FSA at foreca...
# 14  Peak status of the corresponding FSA at foreca...
# 15  Peak status of the corresponding FSA at foreca...
# 16  Peak status of the corresponding FSA at foreca...
# 17  Peak status of the corresponding FSA at foreca...
# 18  Peak status of the corresponding FSA at foreca...
# 19  Peak status of the corresponding FSA at foreca...
# 20  Peak status of the corresponding FSA at foreca...
# 21  Peak status of the corresponding FSA at foreca...
# 22  Peak status of the corresponding FSA at foreca...
# 23  Peak status of the corresponding FSA at foreca...
#
#              threshold_scope
# 0   training_only_fsa_season
# 1   training_only_fsa_season
# 2   training_only_fsa_season
# 3   training_only_fsa_season
# 4   training_only_fsa_season
# 5   training_only_fsa_season
# 6   training_only_fsa_season
# 7   training_only_fsa_season
# 8   training_only_fsa_season
# 9   training_only_fsa_season
# 10  training_only_fsa_season
# 11  training_only_fsa_season
# 12  training_only_fsa_season
# 13  training_only_fsa_season
# 14  training_only_fsa_season
# 15  training_only_fsa_season
# 16  training_only_fsa_season
# 17  training_only_fsa_season
# 18  training_only_fsa_season
# 19  training_only_fsa_season
# 20  training_only_fsa_season
# 21  training_only_fsa_season
# 22  training_only_fsa_season
# 23  training_only_fsa_season

# %%
# Review all framework validation checks
results["framework_validation"]
# Out:
#          fold             role                                       check  \
# 0   fold_2023       validation                             non_empty_train
# 1   fold_2023       validation                        non_empty_evaluation
# 2   fold_2023       validation                   train_precedes_evaluation
# 3   fold_2023       validation                           same_fsa_coverage
# 4   fold_2023       validation                         no_temporal_overlap
# 5   fold_2023       validation                train_origin_is_horizon_safe
# 6   fold_2023       validation           evaluation_origin_is_horizon_safe
# 7   fold_2024       validation                             non_empty_train
# 8   fold_2024       validation                        non_empty_evaluation
# 9   fold_2024       validation                   train_precedes_evaluation
# 10  fold_2024       validation                           same_fsa_coverage
# 11  fold_2024       validation                         no_temporal_overlap
# 12  fold_2024       validation                train_origin_is_horizon_safe
# 13  fold_2024       validation           evaluation_origin_is_horizon_safe
# 14  test_2025             test                             non_empty_train
# 15  test_2025             test                        non_empty_evaluation
# 16  test_2025             test                   train_precedes_evaluation
# 17  test_2025             test                           same_fsa_coverage
# 18  test_2025             test                         no_temporal_overlap
# 19  test_2025             test                train_origin_is_horizon_safe
# 20  test_2025             test           evaluation_origin_is_horizon_safe
# 21     global  forecast_target    all_forecasting_target_columns_available
# 22  fold_2023       validation                      train_horizon_complete
# 23  fold_2023       validation                 evaluation_horizon_complete
# 24  fold_2023       validation            train_h24_within_training_period
# 25  fold_2023       validation     evaluation_h24_within_evaluation_period
# 26  fold_2024       validation                      train_horizon_complete
# 27  fold_2024       validation                 evaluation_horizon_complete
# 28  fold_2024       validation            train_h24_within_training_period
# 29  fold_2024       validation     evaluation_h24_within_evaluation_period
# 30  test_2025             test                      train_horizon_complete
# 31  test_2025             test                 evaluation_horizon_complete
# 32  test_2025             test            train_h24_within_training_period
# 33  test_2025             test     evaluation_h24_within_evaluation_period
# 34        NaN              NaN  final_holdout_after_all_validation_periods
# 35        NaN              NaN       preprocessing_fit_scope_training_only
# 36        NaN              NaN     forecasting_selection_metric_is_primary
# 37        NaN              NaN            peak_selection_metric_is_primary
# 38        NaN              NaN  classification_probability_threshold_valid
# 39        NaN              NaN            forecast_and_peak_horizons_match
#
#    status details latest_validation_end test_start configured_value
# 0    PASS     NaN                   NaT        NaT              NaN
# 1    PASS     NaN                   NaT        NaT              NaN
# 2    PASS     NaN                   NaT        NaT              NaN
# 3    PASS     NaN                   NaT        NaT              NaN
# 4    PASS     NaN                   NaT        NaT              NaN
# 5    PASS     NaN                   NaT        NaT              NaN
# 6    PASS     NaN                   NaT        NaT              NaN
# 7    PASS     NaN                   NaT        NaT              NaN
# 8    PASS     NaN                   NaT        NaT              NaN
# 9    PASS     NaN                   NaT        NaT              NaN
# 10   PASS     NaN                   NaT        NaT              NaN
# 11   PASS     NaN                   NaT        NaT              NaN
# 12   PASS     NaN                   NaT        NaT              NaN
# 13   PASS     NaN                   NaT        NaT              NaN
# 14   PASS     NaN                   NaT        NaT              NaN
# 15   PASS     NaN                   NaT        NaT              NaN
# 16   PASS     NaN                   NaT        NaT              NaN
# 17   PASS     NaN                   NaT        NaT              NaN
# 18   PASS     NaN                   NaT        NaT              NaN
# 19   PASS     NaN                   NaT        NaT              NaN
# 20   PASS     NaN                   NaT        NaT              NaN
# 21   PASS                           NaT        NaT              NaN
# 22   PASS                           NaT        NaT              NaN
# 23   PASS                           NaT        NaT              NaN
# 24   PASS                           NaT        NaT              NaN
# 25   PASS                           NaT        NaT              NaN
# 26   PASS                           NaT        NaT              NaN
# 27   PASS                           NaT        NaT              NaN
# 28   PASS                           NaT        NaT              NaN
# 29   PASS                           NaT        NaT              NaN
# 30   PASS                           NaT        NaT              NaN
# 31   PASS                           NaT        NaT              NaN
# 32   PASS                           NaT        NaT              NaN
# 33   PASS                           NaT        NaT              NaN
# 34   PASS     NaN   2024-12-31 23:00:00 2025-01-01              NaN
# 35   PASS     NaN                   NaT        NaT    training_only
# 36   PASS     NaN                   NaT        NaT              NaN
# 37   PASS     NaN                   NaT        NaT              NaN
# 38   PASS     NaN                   NaT        NaT              NaN
# 39   PASS     NaN                   NaT        NaT              NaN

# %%
# Final validation
validation_ok = (
    results[
        "framework_validation"
    ]["status"]
    .eq("PASS")
    .all()
)

fsa_coverage_ok = (
    results[
        "fsa_coverage"
    ]["status"]
    .eq("PASS")
    .all()
)

assert validation_ok, (
    "Framework validation contains FAIL checks."
)

assert fsa_coverage_ok, (
    "At least one FSA has insufficient fold coverage."
)

print(
    "Modeling Foundation is ready for final review."
)
# Out:
# Modeling Foundation is ready for final review.
