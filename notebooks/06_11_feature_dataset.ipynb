# %% [markdown]
# # 06.11 — Final Feature Dataset
#
# Generate the complete static feature table and inspect the modeling handoff.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists(): PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path: sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = PROJECT_ROOT / 'configs' / 'feature_engineering.yaml'
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/feature_engineering.yaml')

# %%
# Import the Peak-Risk Feature Engineering process
from src.ontario_peak_risk.feature_engineering.build_feature_dataset import build_feature_dataset

# %%
# Run the feature engineering process to build the feature dataset
feature_dataset = build_feature_dataset(CONFIG_PATH)
feature_dataset.shape
# Out:
# e:\Programs\Python\Python313\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Base dataset: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\data\interim\feature_dataset_base.parquet
# Final feature dataset: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\data\processed\feature_dataset.parquet
# Rows: 262,944
# Columns: 100
# Reports: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\reports\feature_engineering
# Documentation: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\docs\feature_engineering
# (262944, 100)

# %%
# Display the first few rows of the feature dataset
feature_dataset.head()
# Out:
#    fsa           timestamp  total_consumption_kwh  reported_premise_count  \
# 0  L4T 2021-01-01 00:00:00                10276.6                    8651
# 1  L4T 2021-01-01 01:00:00                 9585.1                    8651
# 2  L4T 2021-01-01 02:00:00                 9015.5                    8651
# 3  L4T 2021-01-01 03:00:00                 8593.1                    8651
# 4  L4T 2021-01-01 04:00:00                 8353.5                    8651
#
#    source_segment_count  customer_type_count  price_plan_count  \
# 0                     5                    2                 3
# 1                     5                    2                 3
# 2                     5                    2                 3
# 3                     5                    2                 3
# 4                     5                    2                 3
#
#               timestamp_utc         timestamp_toronto       date  ...  \
# ...

# %%
# Display the percentage of missing values for each feature in the dataset
feature_dataset.isna().mean().mul(100).sort_values(ascending=False).head(25).rename('missing_pct').to_frame()
# Out:
#                                          missing_pct
# Wind Chill                                 89.980376
# Hmdx                                       82.395491
# Weather                                    78.641840
# Wind Dir (10s deg)                         50.835159
# Precip. Amount (mm)                        50.046778
# Visibility (km)                            50.007986
# Wind Spd (km/h)                            50.006846
# humidity_rolling_mean_24h                   0.708516
# temperature_rolling_mean_24h                0.681134
# total_consumption_kwh_rolling_std_168h      0.383352
# total_consumption_kwh_rolling_max_168h      0.383352
# total_consumption_kwh_rolling_mean_168h     0.383352
# total_consumption_kwh_lag_168h              0.383352
# total_consumption_kwh_rolling_min_168h      0.383352
# humidity_rolling_mean_6h                    0.199662
# temperature_rolling_mean_6h                 0.192817
# temperature_change_24h                      0.162012
# ...
