# %% [markdown]
# # 06.11 — Final Feature Dataset
#
# Generate the complete static feature table and inspect the modeling handoff

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists(): PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path: sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = PROJECT_ROOT / 'configs' / 'feature_engineering.yaml'
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/configs/feature_engineering.yaml')

# %%
# Import the Peak-Risk Feature Engineering process
from src.ontario_peak_risk.feature_engineering.build_feature_dataset import build_feature_dataset

# %%
# Run the feature engineering process to build the feature dataset
feature_dataset = build_feature_dataset(CONFIG_PATH)
feature_dataset.shape
# Out:
# e:\Programs\Python\Python313\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Feature family counts before generating the summary:
# feature_family
# existing                       47
# target_rolling                 16
# traceability                    8
# temporal_cyclical               8
# target_lag                      6
# weather_rolling                 4
# weather_change                  4
# weather_nonlinear               2
# administrative_or_redundant     2
# interaction                     2
# operational_exogenous           1
# spatial                         1
# target                          1
# Name: count, dtype: int64
# Base dataset: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\data\interim\feature_dataset_base.parquet
# Final feature dataset: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\data\processed\feature_dataset.parquet
# Rows: 262,944
# Columns: 100
# Reports: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\reports\feature_engineering
# Documentation: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\docs\feature_engineering
# (262944, 100)

# %%
# Display the first few rows of the feature dataset
feature_dataset.head()

# %%
# Display the percentage of missing values for each feature in the dataset
feature_dataset.isna().mean().mul(100).sort_values(ascending=False).head(25).rename('missing_pct').to_frame()
