# %% [markdown]
# # 06.01 — Baseline Dataset
#
# Create the modeling baseline without engineered variables.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / 'configs' / 'feature_engineering.yaml'
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/configs/feature_engineering.yaml')

# %%
# Import module to manage the Feature Engineering process
from src.ontario_peak_risk.feature_engineering.common import (
    load_feature_config,
    load_clean_dataset,
    ensure_directories,
)

# %%
# Config Feature Engineering process and Load the dataset
CONFIG, _ = load_feature_config(CONFIG_PATH)
REPORTS_DIR, DOCS_DIR = ensure_directories(CONFIG, PROJECT_ROOT)
clean_dataset = load_clean_dataset(CONFIG, PROJECT_ROOT)
clean_dataset.shape
# Out:
# (262944, 66)

# %%
# Import the function to run baseline Feature Engineering process
from src.ontario_peak_risk.feature_engineering.base_features import build_base_dataset

# %%
# Run the baseline Feature Engineering process
base_dataset, base_dictionary = build_base_dataset(clean_dataset, CONFIG)
base_dataset.shape
# Out:
# (262944, 64)

# %%
# Display the base dictionary
base_dictionary
# Out:
#               feature_name               feature_family  \
# 0                      fsa                      spatial
# 1                timestamp                 traceability
# 2    total_consumption_kwh                       target
# 3   reported_premise_count        operational_exogenous
# 4     source_segment_count                     existing
# ..                     ...                          ...
# 61                    Hmdx                     existing
# 62              Wind Chill                     existing
# 63                 Weather                     existing
# 64              month_name  administrative_or_redundant
# 65            weekday_name  administrative_or_redundant
#
#             source_columns                                        description  \
# 0                      fsa                 Forward Sortation Area identifier.
# 1                timestamp  Retained for audit, geographic reference, or a...
# 2    total_consumption_kwh           Observed electricity consumption target.
# 3   reported_premise_count  Number of premises represented in the hourly c...
# 4     source_segment_count  Existing cleaned predictor retained for prelim...
# ..                     ...                                                ...
# 61                    Hmdx  Existing cleaned predictor retained for prelim...
# 62              Wind Chill  Existing cleaned predictor retained for prelim...
# 63                 Weather  Existing cleaned predictor retained for prelim...
# 64              month_name  Removed from the baseline feature table by exp...
# 65            weekday_name  Removed from the baseline feature table by exp...
#
#     forecasting_candidate  peak_risk_candidate    computation_scope  \
# 0                    True                 True       static_dataset
# 1                   False                False       static_dataset
# 2                   False                False          target_only
# 3                    True                 True  availability_review
# 4                    True                 True       static_dataset
# ..                    ...                  ...                  ...
# 61                   True                 True       static_dataset
# 62                   True                 True       static_dataset
# 63                   True                 True       static_dataset
# 64                  False                False       static_dataset
# 65                  False                False       static_dataset
#
#    leakage_risk
# 0          none
# 1          none
# 2   target_only
# 3          none
# 4          none
# ..          ...
# 61         none
# 62         none
# 63         none
# 64         none
# 65         none
#
# [66 rows x 8 columns]

# %%
# Display the base dataset
base_dataset.head()
# Out:
#    fsa           timestamp  total_consumption_kwh  reported_premise_count  \
# 0  L4T 2021-01-01 00:00:00                10276.6                    8651
# 1  L4T 2021-01-01 01:00:00                 9585.1                    8651
# 2  L4T 2021-01-01 02:00:00                 9015.5                    8651
# 3  L4T 2021-01-01 03:00:00                 8593.1                    8651
# 4  L4T 2021-01-01 04:00:00                 8353.5                    8651
#
#    source_segment_count  customer_type_count  price_plan_count  \
# 0                     5                    2                 3
# 1                     5                    2                 3
# 2                     5                    2                 3
# 3                     5                    2                 3
# 4                     5                    2                 3
#
#               timestamp_utc         timestamp_toronto       date  ...  \
# 0 2021-01-01 05:00:00+00:00 2021-01-01 05:00:00+00:00 2021-01-01  ...
# 1 2021-01-01 06:00:00+00:00 2021-01-01 06:00:00+00:00 2021-01-01  ...
# 2 2021-01-01 07:00:00+00:00 2021-01-01 07:00:00+00:00 2021-01-01  ...
# 3 2021-01-01 08:00:00+00:00 2021-01-01 08:00:00+00:00 2021-01-01  ...
# 4 2021-01-01 09:00:00+00:00 2021-01-01 09:00:00+00:00 2021-01-01  ...
#
#    Dew Point Temp (°C)  Rel Hum (%)  Precip. Amount (mm)  Wind Dir (10s deg)  \
# 0                 -6.4         74.0                  NaN                27.0
# 1                 -6.2         72.0                  NaN                15.0
# 2                 -6.2         75.0                  NaN                18.0
# 3                 -6.1         82.0                  NaN                26.0
# 4                 -5.7         83.0                  NaN                26.0
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Hmdx  Wind Chill  \
# 0              3.0             24.1           100.93  NaN        -4.0
# 1              3.0             24.1           100.93  NaN        -3.0
# 2              5.0             24.1           100.95  NaN        -4.0
# 3              4.0             24.1           101.03  NaN        -5.0
# 4              5.0             24.1           101.02  NaN        -5.0
#
#          Weather
# 0            NaN
# 1          Clear
# 2            NaN
# 3            NaN
# 4  Mostly Cloudy
#
# [5 rows x 64 columns]
