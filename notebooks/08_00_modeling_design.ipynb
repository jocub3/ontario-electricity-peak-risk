# %% [markdown]
# # 08.00 — Modeling Design
#
# Review the common experimental rules before any baseline or candidate model is developed.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "modeling_foundation.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/configs/modeling_foundation.yaml')

# %%
# Import module to manage modeling configuration, feature datasets, and directories
from src.ontario_peak_risk.modeling.common import (
    load_modeling_config,
    load_feature_dataset,
    ensure_modeling_directories,
)

# %%
# Load the modeling configuration, feature dataset, and ensure necessary directories exist
CONFIG, _ = load_modeling_config(CONFIG_PATH)
REPORTS_DIR, DOCS_DIR, OUTPUTS_DIR = ensure_modeling_directories(CONFIG, PROJECT_ROOT)
feature_dataset = load_feature_dataset(CONFIG, PROJECT_ROOT)
feature_dataset.shape
# Out:
# (262944, 100)

# %% [markdown]
# ### Scope
#
# This branch defines shared modeling policy only.
#
# No Forecasting or Peak-Risk model is trained here.

# %%
# Display the modeling configuration
with CONFIG_PATH.open("r", encoding="utf-8") as file:
    modeling_config = yaml.safe_load(file)

modeling_config["modeling"]
# Out:
# {'random_seed': 42,
#  'time': {'time_column': 'timestamp', 'group_column': 'fsa'},
#  'forecasting': {'target_prefix': 'target_h',
#   'horizons': 24,
#   'selection_metric': 'mae',
#   'primary_metrics': ['mae', 'rmse', 'mape'],
#   'secondary_metrics': ['wape', 'bias']},
#  'peak_risk': {'target_column': 'total_consumption_kwh',
#   'percentile_threshold': 0.975,
#   'threshold_grouping': ['fsa', 'season'],
#   'target_prefix': 'peak_h',
#   'horizons': 24,
#   'probability_threshold': 0.5,
#   'selection_metric': 'pr_auc',
#   'primary_metrics': ['precision', 'recall', 'f1', 'pr_auc'],
#   'secondary_metrics': ['roc_auc', 'balanced_accuracy']},
#  'splits': {'validation_folds': [{'name': 'fold_2023',
#     'train_start': '2021-01-01 00:00:00',
#     'train_end': '2022-12-31 23:00:00',
#     'validation_start': '2023-01-01 00:00:00',
#     'validation_end': '2023-12-31 23:00:00'},
#    {'name': 'fold_2024',
#     'train_start': '2021-01-01 00:00:00',
#     'train_end': '2023-12-31 23:00:00',
#     'validation_start': '2024-01-01 00:00:00',
#     'validation_end': '2024-12-31 23:00:00'}],
#   'final_holdout': {'name': 'test_2025',
#    'train_start': '2021-01-01 00:00:00',
#    'train_end': '2024-12-31 23:00:00',
#    'test_start': '2025-01-01 00:00:00',
#    'test_end': '2025-12-31 23:00:00'}},
#  'preprocessing': {'numeric_scaling': {'default_linear': 'standard',
#    'default_tree': 'none',
#    'robust_option': 'robust'},
#   'missing_values': {'numeric_strategy': 'median',
#    'categorical_strategy': 'most_frequent'},
#   'categorical_encoding': {'default_linear': 'one_hot',
#    'default_tree': 'model_specific'},
#   'fit_scope': 'training_only'},
#  'evaluation': {'report_global_metrics': True,
#   'report_by_fsa': True,
#   'report_by_fold': True,
#   'report_by_horizon': True,
#   'preserve_2025_holdout': True}}
