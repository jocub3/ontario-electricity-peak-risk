# %% [markdown]
# # 06.08 — Preliminary Feature Selection
#
# Classify feature priorities without permanently removing predictors.

# %%
# Import libraries
from pathlib import Path
import sys
import pandas as pd

# %%
# define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / 'configs' / 'feature_engineering.yaml'

# %%
# Import the function to build the feature dataset
from src.ontario_peak_risk.feature_engineering.build_feature_dataset import build_feature_dataset

# %%
# Run the function to build the feature dataset
feature_dataset = build_feature_dataset(CONFIG_PATH)
feature_dataset.shape
# Out:
# e:\Programs\Python\Python313\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Feature family counts before generating the summary:
# feature_family
# existing                       47
# target_rolling                 16
# traceability                    8
# temporal_cyclical               8
# target_lag                      6
# weather_rolling                 4
# weather_change                  4
# weather_nonlinear               2
# administrative_or_redundant     2
# interaction                     2
# operational_exogenous           1
# spatial                         1
# target                          1
# Name: count, dtype: int64
# Base dataset: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\data\interim\feature_dataset_base.parquet
# ...

# %%
# Load the preliminary feature selection results
selection = pd.read_csv(PROJECT_ROOT / 'reports' / 'feature_engineering' / '06_07_preliminary_feature_selection.csv')
selection
# Out:
#                       feature         feature_family           dtype  \
# 0                         fsa                spatial        category
# 1                   timestamp           traceability  datetime64[ns]
# 2       total_consumption_kwh                 target         float64
# 3      reported_premise_count  operational_exogenous           Int64
# 4        source_segment_count               existing            Int8
# ..                        ...                    ...             ...
# 95  humidity_rolling_mean_24h        weather_rolling         float64
# 96           heating_degree_c      weather_nonlinear         float64
# 97           cooling_degree_c      weather_nonlinear         float64
# 98         temperature_x_hour            interaction         Float64
# 99      temperature_x_weekend            interaction         Float64
#
#     missing_pct  unique_count preliminary_priority  \
# 0      0.000000             6                 high
# ...

# %%
# Display the number of features per preliminary priority
selection.groupby('preliminary_priority').size().rename('feature_count').to_frame()
# Out:
#                       feature_count
# preliminary_priority
# administrative                    8
# high                             41
# low                               2
# medium                           48
# target                            1
