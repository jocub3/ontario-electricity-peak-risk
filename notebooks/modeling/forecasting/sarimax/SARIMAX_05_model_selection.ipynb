# %% [markdown]
# # SARIMAX 05 — Model Selection / Moderate Tuning
#
# Review the tuning outputs generated during training without refitting SARIMAX.

# %%
# Import libraries
from pathlib import Path
import sys
import json
import pandas as pd

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

REPORTS_DIR = PROJECT_ROOT / "reports" / "modeling" / "forecasting" / "sarimax"
OUTPUTS_DIR = PROJECT_ROOT / "outputs" / "modeling" / "forecasting" / "sarimax"

REPORTS_DIR, OUTPUTS_DIR
# Out:
# (WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/reports/modeling/forecasting/sarimax'),
#  WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/outputs/modeling/forecasting/sarimax'))

# %%
tuning_summary = pd.read_csv(REPORTS_DIR / "SARIMAX_05_tuning_summary.csv")
tuning_details = pd.read_csv(REPORTS_DIR / "SARIMAX_05_tuning_details.csv")
best_specification = json.loads(
    (OUTPUTS_DIR / "best_specification.json").read_text(encoding="utf-8")
)

display(tuning_summary)
# Out:
#    specification_id      mean_mae     mean_rmse   mean_mape
# 0                 2   3906.638341   4579.173799   27.813571
# 1                 3   4004.636195   4775.848122   30.393548
# 2                 1  13729.891965  14398.847441  101.008432

# %%
# Display
best_specification
# Out:
# {'order': [2, 0, 1], 'seasonal_order': [1, 0, 0, 24], 'trend': 'c'}
