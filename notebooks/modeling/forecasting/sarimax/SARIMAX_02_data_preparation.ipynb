# %% [markdown]
# # SARIMAX 02 — Data Preparation
#
# Inspect the compact exogenous-variable design and horizon-specific structure.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "sarimax.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/sarimax.yaml')

# %% [markdown]
# SARIMAX uses deterministic target-time calendar information plus variables observed at forecast origin. Future observed weather is not used.
