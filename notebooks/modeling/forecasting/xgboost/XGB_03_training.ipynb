# %% [markdown]
# # XGB 03 — Training
#
# Run the XGBRegressor candidate workflow on development folds only.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "xgboost_regressor.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/xgboost_regressor.yaml')

# %%
# # Import functions to run XGBoost model
from src.ontario_peak_risk.models.forecasting.xgboost.run_model import run_model

# %%
# Run the model - XGBoost
results = run_model(CONFIG_PATH)
# Out:
# XGBRegressor completed successfully.
# Best parameters: {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.05, 'subsample': 0.8, 'colsample_bytree': 0.8, 'min_child_weight': 5.0, 'reg_lambda': 1.0}
# Final 2025 holdout evaluated: NO

# %%
# Display results
results["fold_metrics"]
# Out:
#         fold         mae         rmse      mape      wape        bias  \
# 0  fold_2023  741.727772  1351.143366  6.864397  8.218963 -447.923609
# 1  fold_2024  471.175112   791.165093  4.997897  5.136220  -54.708367
#
#    n_observations
# 0         1257984
# 1         1261440
