# %% [markdown]
# # XGB 04 — Hyperparameter Tuning
#
# Review the tuning outputs already generated during model training. This notebook does not retrain the model.

# %%
# Import libraries
from pathlib import Path
import sys
import json
import pandas as pd

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

REPORTS_DIR = PROJECT_ROOT / "reports" / "modeling" / "forecasting" / "xgboost"
OUTPUTS_DIR = PROJECT_ROOT / "outputs" / "modeling" / "forecasting" / "xgboost"

REPORTS_DIR, OUTPUTS_DIR
# Out:
# (WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/reports/modeling/forecasting/xgboost'),
#  WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/outputs/modeling/forecasting/xgboost'))

# %%
# Get model data
tuning_summary = pd.read_csv(REPORTS_DIR / "XGB_04_tuning_summary.csv")
tuning_details = pd.read_csv(REPORTS_DIR / "XGB_04_tuning_details.csv")
best_parameters = json.loads((OUTPUTS_DIR / "best_parameters.json").read_text(encoding="utf-8"))

# %%
# Display Tuning summary
display(tuning_summary)
# Out:
#    parameter_id  n_estimators  max_depth  learning_rate  subsample  \
# 0             2           400          6           0.05        0.8
# 1             3           300          6           0.08        0.9
# 2             4           500          4           0.03        0.9
# 3             1           300          4           0.05        0.8
#
#    colsample_bytree  min_child_weight  reg_lambda    mean_mae    mean_rmse  \
# 0               0.8                 5         1.0  572.264737   993.380854
# 1               0.9                 5         2.0  580.704774  1005.684938
# 2               0.9                 3         2.0  583.543951   968.742871
# 3               0.8                 3         1.0  586.406657   967.621146
#
#    mean_mape
# 0   5.667641
# 1   5.739097
# 2   5.952227
# 3   5.996035

# %%
# Display Tuning details
tuning_details
# Out:
#     parameter_id       fold  horizon  n_estimators  max_depth  learning_rate  \
# 0              1  fold_2023        1           300          4           0.05
# 1              1  fold_2023       12           300          4           0.05
# 2              1  fold_2023       24           300          4           0.05
# 3              1  fold_2024        1           300          4           0.05
# 4              1  fold_2024       12           300          4           0.05
# 5              1  fold_2024       24           300          4           0.05
# 6              2  fold_2023        1           400          6           0.05
# 7              2  fold_2023       12           400          6           0.05
# 8              2  fold_2023       24           400          6           0.05
# 9              2  fold_2024        1           400          6           0.05
# 10             2  fold_2024       12           400          6           0.05
# ...

# %%
# Display besta parameters
best_parameters
# Out:
# {'n_estimators': 400,
#  'max_depth': 6,
#  'learning_rate': 0.05,
#  'subsample': 0.8,
#  'colsample_bytree': 0.8,
#  'min_child_weight': 5.0,
#  'reg_lambda': 1.0}
