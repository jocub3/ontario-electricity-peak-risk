# %% [markdown]
# # XGB 02 — Data & Feature Preparation
#
# Inspect the leakage-safe predictor set.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "xgboost_regressor.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/xgboost_regressor.yaml')

# %%
# Import functions to manage XGBoost model
from src.ontario_peak_risk.modeling.common import load_modeling_config, load_feature_dataset
from src.ontario_peak_risk.models.forecasting.xgboost.features import feature_dictionary

# %%
# Config model
FOUNDATION, _ = load_modeling_config(
    PROJECT_ROOT / "configs" / "modeling_foundation.yaml"
)
feature_dataset = load_feature_dataset(FOUNDATION, PROJECT_ROOT)

# Display feacture dictionary
feature_dictionary(feature_dataset)
# Out:
#                            feature         type                   availability
# 0                      target_hour      numeric  forecast_origin_or_historical
# 1                   target_weekday      numeric  forecast_origin_or_historical
# 2                     target_month      numeric  forecast_origin_or_historical
# 3                target_is_weekend      numeric  forecast_origin_or_historical
# 4                  target_hour_sin      numeric  forecast_origin_or_historical
# 5                  target_hour_cos      numeric  forecast_origin_or_historical
# 6               target_weekday_sin      numeric  forecast_origin_or_historical
# 7               target_weekday_cos      numeric  forecast_origin_or_historical
# 8                 target_month_sin      numeric  forecast_origin_or_historical
# 9                 target_month_cos      numeric  forecast_origin_or_historical
# 10                  target_lag_24h      numeric  forecast_origin_or_historical
# ...
