# %% [markdown]
# # RF 01 — Random Forest Design
#
# Review the candidate model design, common fold policy, and tuning scope.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_regressor.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_regressor.yaml')

# %%
# Display config
with CONFIG_PATH.open("r", encoding="utf-8") as file:
    CONFIG = yaml.safe_load(file)
CONFIG
# Out:
# {'model': {'name': 'random_forest_regressor',
#   'branch': 'forecasting/random-forest-regressor',
#   'horizons': 24,
#   'target_prefix': 'target_h',
#   'evaluate_final_holdout': False,
#   'random_seed': 42,
#   'tuning': {'representative_horizons': [1, 12, 24],
#    'parameter_grid': [{'n_estimators': 120,
#      'max_depth': 12,
#      'min_samples_leaf': 1,
#      'max_features': 'sqrt'},
#     {'n_estimators': 120,
#      'max_depth': 20,
#      'min_samples_leaf': 1,
#      'max_features': 'sqrt'},
#     {'n_estimators': 160,
#      'max_depth': 16,
#      'min_samples_leaf': 3,
#      'max_features': 0.7},
#     {'n_estimators': 160,
#      'max_depth': None,
#      'min_samples_leaf': 5,
#      'max_features': 0.7}]}},
#  'paths': {'modeling_foundation_config': 'configs/modeling_foundation.yaml',
#   'feature_dataset': 'data/processed/feature_dataset.parquet',
#   'forecast_targets': 'data/processed/target_definition/forecast_target_complete.parquet',
# ...
