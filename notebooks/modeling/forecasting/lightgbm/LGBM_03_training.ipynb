# %% [markdown]
# # LGBM 03 — Training
#
# Run the LGBMRegressor candidate workflow on development folds only.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "lightgbm_regressor.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/lightgbm_regressor.yaml')

# %%
# Import functions to run Lightgbm model
from src.ontario_peak_risk.models.forecasting.lightgbm.run_model import run_model

# %%
# Run the model - Lightgbm
results = run_model(CONFIG_PATH)
# Out:
# LGBMRegressor completed successfully.
# Best parameters: {'n_estimators': 400, 'num_leaves': 63, 'learning_rate': 0.05, 'max_depth': -1, 'min_child_samples': 30, 'subsample': 0.8, 'colsample_bytree': 0.8, 'reg_lambda': 0.5}
# Final 2025 holdout evaluated: NO

# %%
# Display results
results["fold_metrics"]
# Out:
#         fold         mae         rmse      mape      wape        bias  \
# 0  fold_2023  691.049920  1242.047324  6.508419  7.657410 -382.745748
# 1  fold_2024  470.923983   799.978978  4.963960  5.133483  -43.800165
#
#    n_observations
# 0         1257984
# 1         1261440
