# %% [markdown]
# # LGBM 04 — Hyperparameter Tuning
#
# Review the tuning outputs already generated during model training. This notebook does not retrain the model.

# %%
# Import libraries
from pathlib import Path
import sys
import json
import pandas as pd

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

REPORTS_DIR = PROJECT_ROOT / "reports" / "modeling" / "forecasting" / "lightgbm"
OUTPUTS_DIR = PROJECT_ROOT / "outputs" / "modeling" / "forecasting" / "lightgbm"

REPORTS_DIR, OUTPUTS_DIR
# Out:
# (WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/reports/modeling/forecasting/lightgbm'),
#  WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/outputs/modeling/forecasting/lightgbm'))

# %%
# Get model data
tuning_summary = pd.read_csv(REPORTS_DIR / "LGBM_04_tuning_summary.csv")
tuning_details = pd.read_csv(REPORTS_DIR / "LGBM_04_tuning_details.csv")
best_parameters = json.loads(
    (OUTPUTS_DIR / "best_parameters.json").read_text(encoding="utf-8")
)

# Display Tuning summary
display(tuning_summary)
# Out:
#    parameter_id  n_estimators  num_leaves  learning_rate  max_depth  \
# 0             2           400          63           0.05         -1
# 1             3           300          63           0.08         -1
# 2             4           500          31           0.03         -1
# 3             1           300          31           0.05         -1
#
#    min_child_samples  subsample  colsample_bytree  reg_lambda    mean_mae  \
# 0                 30        0.8               0.8         0.5  553.609158
# 1                 40        0.9               0.9         1.0  556.943887
# 2                 30        0.9               0.9         1.0  565.033176
# 3                 20        0.8               0.8         0.0  567.271943
#
#     mean_rmse  mean_mape
# 0  960.978452   5.508116
# 1  966.003853   5.540215
# 2  964.236071   5.701426
# 3  967.508674   5.716240

# %%
# Display parameters
best_parameters
# Out:
# {'n_estimators': 400,
#  'num_leaves': 63,
#  'learning_rate': 0.05,
#  'max_depth': -1,
#  'min_child_samples': 30,
#  'subsample': 0.8,
#  'colsample_bytree': 0.8,
#  'reg_lambda': 0.5}
