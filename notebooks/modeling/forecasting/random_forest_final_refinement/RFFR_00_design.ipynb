# %% [markdown]
# # RFFR 00 — Controlled Refinement Design
#
# Review the deliberately small search around the already-selected Random Forest configuration.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_final_refinement.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_final_refinement.yaml')

# %%
# Display config
with CONFIG_PATH.open("r", encoding="utf-8") as handle:
    CONFIG = yaml.safe_load(handle)
CONFIG["incumbent"], CONFIG["refinement"]
CONFIG
# Out:
# {'phase': {'name': 'random_forest_forecasting_final_refinement',
#   'branch': 'forecasting/random-forest-final-refinement',
#   'evaluate_final_holdout': False},
#  'incumbent': {'n_estimators': 160,
#   'max_depth': None,
#   'min_samples_leaf': 5,
#   'max_features': 0.7},
#  'refinement': {'representative_horizons': [1, 12, 24],
#   'minimum_mae_improvement_pct_to_replace_incumbent': 0.25,
#   'parameter_grid': [{'refinement_id': 'R0_incumbent',
#     'n_estimators': 160,
#     'max_depth': None,
#     'min_samples_leaf': 5,
#     'max_features': 0.7},
#    {'refinement_id': 'R1_more_trees',
#     'n_estimators': 220,
#     'max_depth': None,
#     'min_samples_leaf': 5,
#     'max_features': 0.7},
#    {'refinement_id': 'R2_leaf_3',
#     'n_estimators': 180,
#     'max_depth': None,
#     'min_samples_leaf': 3,
#     'max_features': 0.7},
#    {'refinement_id': 'R3_features_08',
#     'n_estimators': 180,
#     'max_depth': None,
#     'min_samples_leaf': 5,
# ...

# %% [markdown]
# ### Scope
#
# This refinement does **not** change:
#
# - features;
# - preprocessing;
# - temporal folds;
# - target definition;
# - evaluation metrics.
#
# Only four nearby hyperparameter configurations are compared on h+1, h+12 and h+24.
