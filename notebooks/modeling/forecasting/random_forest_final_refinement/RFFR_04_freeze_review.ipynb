# %% [markdown]
# # RFFR 04 — Freeze Review
#
# Inspect the frozen Random Forest forecasting configuration before opening the 2025 holdout.

# %%
# Import libraries
from pathlib import Path
import sys
import json

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_final_refinement.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_final_refinement.yaml')

# %%
# Define config
OUTPUTS_DIR = (
    PROJECT_ROOT
    / "outputs"
    / "modeling"
    / "forecasting"
    / "random_forest_final_refinement"
)

manifest = json.loads(
    (OUTPUTS_DIR / "RF_FORECASTING_FINAL_FREEZE_MANIFEST.json")
    .read_text(encoding="utf-8")
)

# Diplay manifest
manifest
# Out:
# {'status': 'FROZEN_FOR_FINAL_HOLDOUT',
#  'task': 'forecasting',
#  'algorithm': 'RandomForestRegressor',
#  'forecast_horizons': 24,
#  'hyperparameters': {'n_estimators': 160,
#   'max_depth': None,
#   'min_samples_leaf': 5,
#   'max_features': 0.7},
#  'feature_policy': 'Use the existing Random Forest forecasting feature set unchanged.',
#  'preprocessing_policy': 'Use the existing Random Forest forecasting preprocessing unchanged.',
#  'selection_evidence': {'selected_refinement_id': 'R0_incumbent',
#   'mean_mae': 528.7229365406797,
#   'minimum_improvement_pct_required': 0.25,
#   'decision': 'KEEP_INCUMBENT: no local alternative exceeded the configured minimum MAE improvement required to justify changing the already-selected forecasting model.',
#   'representative_horizons': [1, 12, 24],
#   'development_folds_only': True},
#  'original_model_config_sha256': '5623240c29a786479d26025f036f4ef8e1302de50d322129405477919c0fd7f9',
# ...

# %% [markdown]
# ## Approval gate
#
# Confirm:
#
# - algorithm is RandomForestRegressor;
# - selected parameters match the refinement decision;
# - features/preprocessing remain unchanged;
# - `final_2025_holdout_evaluated` is `false`.
#
# Once approved, do not change the configuration based on the 2025 result.
