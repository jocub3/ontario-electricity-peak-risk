# %% [markdown]
# # RFFR 02 — Quick Refinement Run
#
# Run only the local hyperparameter refinement on representative horizons. This is the only notebook in the phase that fits new Random Forest models.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_final_refinement.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_final_refinement.yaml')

# %%
# Import modules for Refinement Random Forest model 
from src.ontario_peak_risk.models.forecasting.random_forest_final_refinement.run_refinement import (
    run_refinement,
)

# %%
# Run refinement 
results = run_refinement(CONFIG_PATH)
# Out:
# ...
# RANDOM FOREST FORECASTING FINAL REFINEMENT COMPLETED
# Selected refinement: R0_incumbent
# Selected parameters: {'n_estimators': 160, 'max_depth': None, 'min_samples_leaf': 5, 'max_features': 0.7}
# Decision: KEEP_INCUMBENT: no local alternative exceeded the configured minimum MAE improvement required to justify changing the already-selected forecasting model.
# Freeze manifest: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\outputs\modeling\forecasting\random_forest_final_refinement\RF_FORECASTING_FINAL_FREEZE_MANIFEST.json
# 2025 final holdout evaluated: NO
# ...

# %%
# Display details
display(results["details"])
# Out:
#     parameter_id       fold  ...  n_observations   refinement_id
# 0              1  fold_2023  ...           52416    R0_incumbent
# 1              1  fold_2023  ...           52416    R0_incumbent
# 2              1  fold_2023  ...           52416    R0_incumbent
# 3              1  fold_2024  ...           52560    R0_incumbent
# 4              1  fold_2024  ...           52560    R0_incumbent
# 5              1  fold_2024  ...           52560    R0_incumbent
# 6              2  fold_2023  ...           52416   R1_more_trees
# 7              2  fold_2023  ...           52416   R1_more_trees
# 8              2  fold_2023  ...           52416   R1_more_trees
# 9              2  fold_2024  ...           52560   R1_more_trees
# 10             2  fold_2024  ...           52560   R1_more_trees
# 11             2  fold_2024  ...           52560   R1_more_trees
# 12             3  fold_2023  ...           52416       R2_leaf_3
# ...

# %%
# Display ranking
display(results["ranking"])
# Out:
#     refinement_id  ...                                           decision
# 0   R1_more_trees  ...  KEEP_INCUMBENT: no local alternative exceeded ...
# 1    R0_incumbent  ...  KEEP_INCUMBENT: no local alternative exceeded ...
# 2       R2_leaf_3  ...  KEEP_INCUMBENT: no local alternative exceeded ...
# 3  R3_features_08  ...  KEEP_INCUMBENT: no local alternative exceeded ...
#
# [4 rows x 10 columns]

# %%
# Display parameters
print("Selected:", results["selected_parameters"])
# Out:
# Selected: {'n_estimators': 160, 'max_depth': None, 'min_samples_leaf': 5, 'max_features': 0.7}
