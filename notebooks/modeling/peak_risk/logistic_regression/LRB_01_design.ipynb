# %% [markdown]
# # LRB 01 — Logistic Regression Baseline Design
#
# Review the fixed baseline configuration, predictor set, preprocessing policy, and protected holdout rule.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "logistic_regression_peak_baseline.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/configs/logistic_regression_peak_baseline.yaml')

# %%
# Display config
with CONFIG_PATH.open("r", encoding="utf-8") as file:
    CONFIG = yaml.safe_load(file)

CONFIG
# Out:
# {'model': {'name': 'logistic_regression_peak_baseline',
#   'branch': 'peak-risk/logistic-regression-baseline',
#   'horizons': 24,
#   'target_prefix': 'peak_h',
#   'probability_threshold': 0.5,
#   'evaluate_final_holdout': False,
#   'logistic_regression': {'C': 1.0,
#    'max_iter': 1000,
#    'solver': 'lbfgs',
#    'class_weight': None}},
#  'paths': {'modeling_foundation_config': 'configs/modeling_foundation.yaml',
#   'feature_dataset': 'data/processed/feature_dataset.parquet',
#   'reports_dir': 'reports/modeling/peak_risk/logistic_regression',
#   'docs_dir': 'docs/modeling/peak_risk/logistic_regression',
#   'outputs_dir': 'outputs/modeling/peak_risk/logistic_regression'}}
