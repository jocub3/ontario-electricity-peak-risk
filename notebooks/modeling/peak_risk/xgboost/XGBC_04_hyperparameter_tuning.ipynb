# %% [markdown]
# # XGBC 04 — Hyperparameter Tuning
#
# Review the saved moderate-tuning results. This notebook does not retrain the classifier.

# %%
# Import libraries
from pathlib import Path
import sys
import json
import pandas as pd

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "xgboost_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/xgboost_classifier.yaml')

# %%
# Display Tuning

REPORTS_DIR = PROJECT_ROOT / "reports" / "modeling" / "peak_risk" / "xgboost"
OUTPUTS_DIR = PROJECT_ROOT / "outputs" / "modeling" / "peak_risk" / "xgboost"

tuning_summary = pd.read_csv(
    REPORTS_DIR / "XGBC_04_tuning_summary.csv"
)
tuning_details = pd.read_csv(
    REPORTS_DIR / "XGBC_04_tuning_details.csv"
)
best_parameters = json.loads(
    (OUTPUTS_DIR / "best_parameters.json").read_text(encoding="utf-8")
)

display(tuning_summary)
# Out:
#    parameter_id  mean_pr_auc  mean_roc_auc   mean_f1  mean_recall  \
# 0             2     0.655594      0.950005  0.547135     0.580021
# 1             3     0.654077      0.948724  0.541058     0.540409
# 2             1     0.642731      0.944621  0.532830     0.710639
#
#    mean_precision  total_seconds
# 0        0.636398      50.321717
# 1        0.665392      28.349226
# 2        0.500933      34.978165

# %%
# Displya parameter
best_parameters
# Out:
# {'n_estimators': 400,
#  'max_depth': 6,
#  'learning_rate': 0.05,
#  'subsample': 0.8,
#  'colsample_bytree': 0.8,
#  'min_child_weight': 5,
#  'reg_lambda': 1.0,
#  'imbalance_multiplier': 1.0}
