# %% [markdown]
# # XGBC 03 — Training
#
# Run tuning and full development validation for XGBClassifier. Progress and ETA are printed while the model runs.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "xgboost_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/xgboost_classifier.yaml')

# %%
# Import functions to run XGBoos Classifier model
from src.ontario_peak_risk.models.peak_risk.xgboost.run_model import (
    run_model,
)

# %%
# Run the model - XGBoos Classifier
results = run_model(CONFIG_PATH, resume=True,)
# Out:
# ...
# XGBClassifier — PEAK-RISK CANDIDATE
# Official threshold: 0.50
# Selection metric: PR-AUC
# Final 2025 holdout evaluated: NO
# ...
# Tuning tasks: 18 (3 parameter sets × 2 folds × 3 horizons)
# [Tuning 1/18] params=1 | fold_2023 | h+1 | PR-AUC=0.6995 | time=6s | ETA=1m 57s
# [Tuning 2/18] params=1 | fold_2023 | h+12 | PR-AUC=0.5463 | time=5s | ETA=1m 42s
# [Tuning 3/18] params=1 | fold_2023 | h+24 | PR-AUC=0.5720 | time=4s | ETA=1m 26s
# [Tuning 4/18] params=1 | fold_2024 | h+1 | PR-AUC=0.8260 | time=5s | ETA=1m 19s
# [Tuning 5/18] params=1 | fold_2024 | h+12 | PR-AUC=0.6267 | time=7s | ETA=1m 18s
# [Tuning 6/18] params=1 | fold_2024 | h+24 | PR-AUC=0.5859 | time=4s | ETA=1m 09s
# [Tuning 7/18] params=2 | fold_2023 | h+1 | PR-AUC=0.7606 | time=7s | ETA=1m 06s
# [Tuning 8/18] params=2 | fold_2023 | h+12 | PR-AUC=0.5730 | time=10s | ETA=1m 05s
# [Tuning 9/18] params=2 | fold_2023 | h+24 | PR-AUC=0.5632 | time=10s | ETA=1m 02s
# ...

# %%
# Display resutls - global_metrics
display(results["global_metrics"])
# Out:
#                 model  precision    recall        f1  balanced_accuracy  \
# 0  xgboost_classifier    0.59633  0.459057  0.518766           0.716962
#
#    n_observations  positive_rate_pct  predicted_positive_rate_pct  \
# 0         2519424           7.482544                     5.760086
#
#    brier_score    pr_auc  roc_auc
# 0     0.050577  0.556495  0.91758

# %%
# Display resutls - Fold metrics
display(results["fold_metrics"])
# Out:
#         fold  precision    recall        f1  balanced_accuracy  \
# 0  fold_2023   0.738489  0.326038  0.452361           0.655909
# 1  fold_2024   0.493535  0.821852  0.616720           0.893313
#
#    n_observations  positive_rate_pct  predicted_positive_rate_pct  \
# 0         1257984          10.965243                     4.841079
# 1         1261440           4.009386                     6.676576
#
#    brier_score    pr_auc   roc_auc
# 0     0.071861  0.612423  0.915251
# 1     0.029352  0.670904  0.978510
