# %% [markdown]
# # LGBC 04 — Hyperparameter Tuning
#
# Review the saved moderate-tuning results. This notebook does not retrain the classifier.

# %%
# Import libraries
from pathlib import Path
import sys

import json
import pandas as pd

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "lightgbm_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/lightgbm_classifier.yaml')

# %%
REPORTS_DIR = PROJECT_ROOT / "reports" / "modeling" / "peak_risk" / "lightgbm"
OUTPUTS_DIR = PROJECT_ROOT / "outputs" / "modeling" / "peak_risk" / "lightgbm"

tuning_summary = pd.read_csv(
    REPORTS_DIR / "LGBC_04_tuning_summary.csv"
)
tuning_details = pd.read_csv(
    REPORTS_DIR / "LGBC_04_tuning_details.csv"
)
best_parameters = json.loads(
    (OUTPUTS_DIR / "best_parameters.json").read_text(encoding="utf-8")
)

display(tuning_summary)
# Out:
#    parameter_id  mean_pr_auc  mean_roc_auc   mean_f1  mean_recall  \
# 0             1     0.642454      0.947158  0.533778     0.600322
# 1             2     0.640610      0.942185  0.501515     0.478523
# 2             3     0.638940      0.942165  0.486478     0.441179
#
#    mean_precision  total_seconds
# 0        0.611945      26.189789
# 1        0.696830      34.121695
# 2        0.714366      28.377937

# %%
best_parameters
# Out:
# {'n_estimators': 300,
#  'num_leaves': 31,
#  'learning_rate': 0.05,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'subsample': 0.8,
#  'colsample_bytree': 0.8,
#  'reg_lambda': 0.0,
#  'imbalance_multiplier': 1.0}
