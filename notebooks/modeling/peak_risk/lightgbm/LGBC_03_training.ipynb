# %% [markdown]
# # LGBC 03 — Training
#
# Run tuning and full development validation for LGBMClassifier. Progress and ETA are printed while the model runs.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "lightgbm_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/lightgbm_classifier.yaml')

# %%
# Import functions to run Lightgbm Classifier model
from src.ontario_peak_risk.models.peak_risk.lightgbm.run_model import (run_model,)

# %%
# Run the model - Lightgbm Classifier
results = run_model(CONFIG_PATH, resume=True,)
# Out:
# ...
# LGBMClassifier — PEAK-RISK CANDIDATE
# Official threshold: 0.50
# Selection metric: PR-AUC
# Final 2025 holdout evaluated: NO
# ...
# Tuning tasks: 18 (3 parameter sets × 2 folds × 3 horizons)
# [Tuning 1/18] params=1 | fold_2023 | h+1 | PR-AUC=0.7395 | time=4s | ETA=1m 17s
# [Tuning 2/18] params=1 | fold_2023 | h+12 | PR-AUC=0.5670 | time=4s | ETA=1m 08s
# [Tuning 3/18] params=1 | fold_2023 | h+24 | PR-AUC=0.5428 | time=3s | ETA=1m 00s
# [Tuning 4/18] params=1 | fold_2024 | h+1 | PR-AUC=0.8440 | time=4s | ETA=57s
# [Tuning 5/18] params=1 | fold_2024 | h+12 | PR-AUC=0.5747 | time=5s | ETA=55s
# [Tuning 6/18] params=1 | fold_2024 | h+24 | PR-AUC=0.5866 | time=4s | ETA=52s
# [Tuning 7/18] params=2 | fold_2023 | h+1 | PR-AUC=0.7326 | time=5s | ETA=49s
# [Tuning 8/18] params=2 | fold_2023 | h+12 | PR-AUC=0.5281 | time=5s | ETA=45s
# [Tuning 9/18] params=2 | fold_2023 | h+24 | PR-AUC=0.5598 | time=4s | ETA=41s
# [Tuning 10/18] params=2 | fold_2024 | h+1 | PR-AUC=0.8523 | time=6s | ETA=38s
# ...

# %%
# Display resutls - global_metrics
display(results["global_metrics"])
# Out:
#                  model  precision    recall        f1  balanced_accuracy  \
# 0  lightgbm_classifier   0.555288  0.470382  0.509321           0.719957
#
#    n_observations  positive_rate_pct  predicted_positive_rate_pct  \
# 0         2519424           7.482544                     6.338433
#
#    brier_score    pr_auc   roc_auc
# 0     0.053348  0.532379  0.909176

# %%
# Display resutls - Fold metrics
display(results["fold_metrics"])
# Out:
#         fold  precision    recall        f1  balanced_accuracy  \
# 0  fold_2023   0.717059  0.325871  0.448101           0.655018
# 1  fold_2024   0.450744  0.864521  0.592546           0.910260
#
#    n_observations  positive_rate_pct  predicted_positive_rate_pct  \
# 0         1257984          10.965243                     4.983211
# 1         1261440           4.009386                     7.689942
#
#    brier_score    pr_auc   roc_auc
# 0     0.073181  0.593187  0.910050
# 1     0.033569  0.665852  0.978672
