# %% [markdown]
# # RFC 03 — Training
#
# Run tuning and full development validation for RandomForestClassifier. Progress and ETA are printed while the model runs.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_classifier.yaml')

# %%
# Import functions to run Ramdon Forest Classifier model
from src.ontario_peak_risk.models.peak_risk.random_forest.run_model import (
    run_model,
)

# %%
# Run the model - Ramdon Forest Classifier
results = run_model(CONFIG_PATH, resume=True,)
# Out:
# ...
# RandomForestClassifier — PEAK-RISK CANDIDATE
# Official threshold: 0.50
# Selection metric: PR-AUC
# Final 2025 holdout evaluated: NO
# ...
# Tuning tasks: 18 (3 parameter sets × 2 folds × 3 horizons)
# [Tuning 1/18] params=1 | fold_2023 | h+1 | PR-AUC=0.6400 | time=18s | ETA=5m 22s
# [Tuning 2/18] params=1 | fold_2023 | h+12 | PR-AUC=0.5132 | time=18s | ETA=4m 58s
# [Tuning 3/18] params=1 | fold_2023 | h+24 | PR-AUC=0.4995 | time=22s | ETA=4m 58s
# [Tuning 4/18] params=1 | fold_2024 | h+1 | PR-AUC=0.7767 | time=36s | ETA=5m 36s
# [Tuning 5/18] params=1 | fold_2024 | h+12 | PR-AUC=0.5718 | time=37s | ETA=5m 46s
# [Tuning 6/18] params=1 | fold_2024 | h+24 | PR-AUC=0.5511 | time=37s | ETA=5m 41s
# [Tuning 7/18] params=2 | fold_2023 | h+1 | PR-AUC=0.6705 | time=1m 47s | ETA=7m 16s
# [Tuning 8/18] params=2 | fold_2023 | h+12 | PR-AUC=0.5982 | time=1m 48s | ETA=8m 02s
# [Tuning 9/18] params=2 | fold_2023 | h+24 | PR-AUC=0.5752 | time=1m 50s | ETA=8m 16s
# ...

# %%
display(results["global_metrics"])
# Out:
#                       model  precision    recall        f1  balanced_accuracy  \
# 0  random_forest_classifier   0.669067  0.355315  0.464143           0.670551
#
#    n_observations  positive_rate_pct  predicted_positive_rate_pct  \
# 0         2519424           7.482544                     3.973686
#
#    brier_score    pr_auc   roc_auc
# 0      0.04464  0.579137  0.941053

# %%
display(results["fold_metrics"])
# Out:
#         fold  precision    recall        f1  balanced_accuracy  \
# 0  fold_2023   0.759171  0.233303  0.356919           0.612094
# 1  fold_2024   0.602897  0.688093  0.642684           0.834581
#
#    n_observations  positive_rate_pct  predicted_positive_rate_pct  \
# 0         1257984          10.965243                     3.369757
# 1         1261440           4.009386                     4.575961
#
#    brier_score    pr_auc   roc_auc
# 0     0.066639  0.628399  0.933096
# 1     0.022701  0.672704  0.979909
