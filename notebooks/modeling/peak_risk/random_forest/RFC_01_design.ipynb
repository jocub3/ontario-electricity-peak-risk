# %% [markdown]
# # RFC 01 — Design
#
# Review the RandomForestClassifier Peak-Risk design before execution.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_classifier.yaml')

# %%
# Display config
with CONFIG_PATH.open("r", encoding="utf-8") as file:
    CONFIG = yaml.safe_load(file)

CONFIG
# Out:
# {'model': {'name': 'random_forest_classifier',
#   'branch': 'peak-risk/random-forest-classifier',
#   'horizons': 24,
#   'target_prefix': 'peak_h',
#   'probability_threshold': 0.5,
#   'peak_percentile': 0.975,
#   'evaluate_final_holdout': False,
#   'random_seed': 42,
#   'tuning': {'representative_horizons': [1, 12, 24],
#    'selection_metric': 'pr_auc',
#    'parameter_grid': [{'n_estimators': 250,
#      'max_depth': 14,
#      'min_samples_leaf': 5,
#      'max_features': 'sqrt',
#      'class_weight': 'balanced_subsample'},
#     {'n_estimators': 400,
#      'max_depth': None,
#      'min_samples_leaf': 8,
#      'max_features': 0.7,
#      'class_weight': 'balanced_subsample'},
#     {'n_estimators': 300,
#      'max_depth': 20,
#      'min_samples_leaf': 10,
#      'max_features': 0.5,
#      'class_weight': 'balanced'}]}},
#  'paths': {'modeling_foundation_config': 'configs/modeling_foundation.yaml',
#   'feature_dataset': 'data/processed/feature_dataset.parquet',
# ...

# %% [markdown]
# ### Common rules
#
# - Peak threshold: P97.5 by FSA + season, fitted on training only.
# - Horizons: h+1 ... h+24.
# - Common comparison probability threshold: 0.50.
# - Selection metric: PR-AUC.
# - 2025 final holdout: protected.
# - Alternative thresholds: diagnostic only at this stage.
