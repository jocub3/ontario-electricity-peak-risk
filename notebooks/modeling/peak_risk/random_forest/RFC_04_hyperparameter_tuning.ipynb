# %% [markdown]
# # RFC 04 — Hyperparameter Tuning
#
# Review the saved moderate-tuning results. This notebook does not retrain the classifier.

# %%
# Import libraries
from pathlib import Path
import sys
import json
import pandas as pd

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "random_forest_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/random_forest_classifier.yaml')

# %%
REPORTS_DIR = PROJECT_ROOT / "reports" / "modeling" / "peak_risk" / "random_forest"
OUTPUTS_DIR = PROJECT_ROOT / "outputs" / "modeling" / "peak_risk" / "random_forest"

tuning_summary = pd.read_csv(
    REPORTS_DIR / "RFC_04_tuning_summary.csv"
)
tuning_details = pd.read_csv(
    REPORTS_DIR / "RFC_04_tuning_details.csv"
)
best_parameters = json.loads(
    (OUTPUTS_DIR / "best_parameters.json").read_text(encoding="utf-8")
)

display(tuning_summary)
# Out:
#    parameter_id  mean_pr_auc  mean_roc_auc   mean_f1  mean_recall  \
# 0             3     0.650407      0.955273  0.506326     0.460438
# 1             2     0.639007      0.951504  0.463171     0.397232
# 2             1     0.592043      0.941420  0.511184     0.520615
#
#    mean_precision  total_seconds
# 0        0.688728     362.074318
# 1        0.708547     822.216512
# 2        0.604007     170.633045

# %%
# 
best_parameters
# Out:
# {'n_estimators': 300,
#  'max_depth': 20,
#  'min_samples_leaf': 10,
#  'max_features': 0.5,
#  'class_weight': 'balanced'}
