# %% [markdown]
# # HGB 01 — HistGradientBoosting Design
#
# Review the candidate classifier design, tuning scope, and shared Peak-Risk policy.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define the root directory of the project and config file
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs" / "hist_gradient_boosting_classifier.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/hist_gradient_boosting_classifier.yaml')

# %%
# Display config
with CONFIG_PATH.open("r", encoding="utf-8") as file:
    CONFIG = yaml.safe_load(file)
CONFIG
# Out:
# {'model': {'name': 'hist_gradient_boosting_classifier',
#   'branch': 'peak-risk/hist-gradient-boosting-classifier',
#   'horizons': 24,
#   'target_prefix': 'peak_h',
#   'probability_threshold': 0.5,
#   'evaluate_final_holdout': False,
#   'random_seed': 42,
#   'tuning': {'representative_horizons': [1, 12, 24],
#    'parameter_grid': [{'learning_rate': 0.05,
#      'max_iter': 160,
#      'max_leaf_nodes': 15,
#      'min_samples_leaf': 20,
#      'l2_regularization': 0.0},
#     {'learning_rate': 0.05,
#      'max_iter': 200,
#      'max_leaf_nodes': 31,
#      'min_samples_leaf': 30,
#      'l2_regularization': 0.5},
#     {'learning_rate': 0.08,
#      'max_iter': 160,
#      'max_leaf_nodes': 31,
#      'min_samples_leaf': 40,
#      'l2_regularization': 1.0},
#     {'learning_rate': 0.1,
#      'max_iter': 120,
#      'max_leaf_nodes': 15,
#      'min_samples_leaf': 30,
#      'l2_regularization': 1.0}]}},
# ...
