# %% [markdown]
# # XGBFR 05 — Select Operational Threshold
#
# Select a validation-only threshold using explicit fold-level Recall and Precision guardrails and worst-fold F1.

# %%
# Import libraries
from pathlib import Path
import sys

import yaml
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = (
    PROJECT_ROOT
    / "configs"
    / "peak_risk_final_refinement.yaml"
)

CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/peak_risk_final_refinement.yaml')

# %%
# Import module for Final Refinement Analysis
from src.ontario_peak_risk.models.peak_risk.final_refinement.run_refinement import (
    run_final_refinement,
)

# %%
# Run final Refinement
results = run_final_refinement(CONFIG_PATH)
# Out:
# ...
# XGBOOST PEAK-RISK FINAL REFINEMENT COMPLETED
# Selected operational threshold: 0.06
# Algorithm / features / hyperparameters: unchanged
# Freeze manifest: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\DataLocal\ontario-electricity-peak-risk\outputs\modeling\peak_risk\xgboost_final_refinement\XGBC_FINAL_FREEZE_MANIFEST.json
# 2025 final holdout evaluated: NO
# ...

# %%
# Display the Selected operational threshold
print("Selected operational threshold:", results["selected_threshold"])
# Out:
# Selected operational threshold: 0.06

# %%
# Display feasible thresholds table
display(results["feasible_thresholds"].head(20))
# Out:
#    threshold  min_precision  mean_precision  max_precision  min_recall  \
# 0       0.06       0.256558        0.395498       0.534439    0.607274
# 1       0.05       0.244794        0.382479       0.520164    0.627319
# 2       0.04       0.231365        0.367053       0.502740    0.651793
# 3       0.03       0.215181        0.348445       0.481709    0.683394
#
#    mean_recall  max_recall  worst_fold_f1   mean_f1  f1_range  \
# 0     0.791260    0.975245       0.406245  0.487389  0.162289
# 1     0.802814    0.978310       0.391601  0.480170  0.177137
# 2     0.816633    0.981473       0.374459  0.471052  0.193186
# 3     0.834134    0.984874       0.353194  0.459145  0.211901
#
#    worst_fold_balanced_accuracy  mean_balanced_accuracy  \
# 0                      0.771062                0.849832
# 1                      0.778025                0.852074
# 2                      0.786198                0.854419
# 3                      0.796419                0.856919
#
# ...

# %%
# Display Global results
display(results["selected_evaluation"]["global"])
# Out:
#    threshold  precision    recall        f1  balanced_accuracy  true_positive  \
# 0       0.06    0.38136  0.705995  0.495217           0.806685         133092
#
#    false_positive  false_negative  true_negative  missed_peak_rate_pct  \
# 0          215901           55425        2115006             29.400532
#
#    false_alarm_rate_pct  predicted_peak_rate_pct  actual_peak_rate_pct  \
# 0              9.262532                13.852095              7.482544
#
#    n_observations
# 0         2519424

# %%
# Display Fold results
display(results["selected_evaluation"]["fold"])
# Out:
#         fold  threshold  precision    recall        f1  balanced_accuracy  \
# 0  fold_2023       0.06   0.534439  0.607274  0.568533           0.771062
# 1  fold_2024       0.06   0.256558  0.975245  0.406245           0.928603
#
#    true_positive  false_positive  false_negative  true_negative  \
# 0          83768           72972           54173        1047071
# 1          49324          142929            1252        1067935
#
#    missed_peak_rate_pct  false_alarm_rate_pct  predicted_peak_rate_pct  \
# 0             39.272588              6.515107                12.459618
# 1              2.475482             11.803885                15.240757
#
#    actual_peak_rate_pct  n_observations
# 0             10.965243         1257984
# 1              4.009386         1261440

# %% [markdown]
# ### Important
#
# The selected threshold is a **development decision**.
#
# Review:
#
# - selected fold Recall;
# - selected fold Precision;
# - false-negative rate;
# - M9W-2023 behavior;
# - horizon behavior;
# - local threshold sensitivity.
