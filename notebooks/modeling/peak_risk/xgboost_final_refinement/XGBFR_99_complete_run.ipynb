# %% [markdown]
# # XGBFR 99 — Complete Final Refinement Run
#
# Reproduce the full validation-only threshold refinement and freeze process. This notebook never evaluates 2025.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = (
    PROJECT_ROOT
    / "configs"
    / "peak_risk_final_refinement.yaml"
)

# %%
from src.ontario_peak_risk.modeling.peak_risk.final_refinement.run_refinement import (
    run_final_refinement,
)

results = run_final_refinement(CONFIG_PATH)

print("Operational threshold:", results["selected_threshold"])
print("2025 holdout evaluated: NO")
