# %% [markdown]
# # XGBFR 00 — Final Refinement Design
#
# Freeze all XGBoost model-development choices except the operational classification threshold. The 2025 holdout remains protected.

# %%
# Import libraries
from pathlib import Path
import sys
import yaml

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = (
    PROJECT_ROOT
    / "configs"
    / "peak_risk_final_refinement.yaml"
)
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/peak_risk_final_refinement.yaml')

# %%
# Display config
with CONFIG_PATH.open("r", encoding="utf-8") as handle:
    CONFIG = yaml.safe_load(handle)
CONFIG
# Out:
# {'phase': {'name': 'peak_risk_final_refinement',
#   'branch': 'peak-risk/xgboost-final-refinement',
#   'selected_model': 'XGBoostClassifier',
#   'evaluate_final_holdout': False},
#  'paths': {'validation_predictions': 'outputs/modeling/peak_risk/xgboost/xgboost_classifier_validation_predictions.parquet',
#   'best_parameters': 'outputs/modeling/peak_risk/xgboost/best_parameters.json',
#   'feature_dictionary': 'reports/modeling/peak_risk/xgboost/XGBC_02_feature_dictionary.csv',
#   'reports_dir': 'reports/modeling/peak_risk/xgboost_final_refinement',
#   'figures_dir': 'reports/figures/modeling/peak_risk/xgboost_final_refinement',
#   'outputs_dir': 'outputs/modeling/peak_risk/xgboost_final_refinement',
#   'docs_dir': 'docs/modeling/peak_risk/xgboost_final_refinement'},
#  'threshold_analysis': {'min_threshold': 0.02,
#   'max_threshold': 0.9,
#   'step': 0.01,
#   'minimum_recall_each_fold': 0.6,
#   'minimum_precision_each_fold': 0.2,
#   'selection_metric': 'worst_fold_f1',
# ...

# %% [markdown]
# ### Decision still open
#
# Only the operational probability threshold is still open.
#
# The following are **not** changed in this phase:
#
# - algorithm;
# - features;
# - hyperparameters;
# - Peak definition;
# - preprocessing.
#
# Threshold selection uses development validation predictions only.
