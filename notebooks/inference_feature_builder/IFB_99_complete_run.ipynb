# %% [markdown]
# # IFB 99 — Complete Operational Run
#
# Single entry point for a real future request after incremental demand and weather files have been supplied.

# %%
from pathlib import Path
import sys
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = Path.cwd()
while (
    not (PROJECT_ROOT / "src").exists()
    and PROJECT_ROOT != PROJECT_ROOT.parent
):
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = (
    PROJECT_ROOT
    / "configs"
    / "inference_feature_builder.yaml"
)

# %%
from src.ontario_peak_risk.inference_feature_builder.run_ifb import (
    run_ifb,
)

# Example only. Before uncommenting:
# - add enough recent observed-demand rows to data/operational/demand/
# - add optional observed weather updates to data/operational/weather/history/
# - add a complete h0...h24 weather forecast to data/operational/weather/forecast/
#
# FORECAST_ORIGIN = pd.Timestamp("2026-08-27 00:00:00")
#
# results = run_ifb(
#     CONFIG_PATH,
#     forecast_origin=FORECAST_ORIGIN,
#     execute_models=True,
# )
#
# display(results["prediction"])
# print(results["manifest"])

# %% [markdown]
# A real operational run intentionally fails if recent observed demand is
# incomplete. The system reports what is missing rather than filling a months-long
# gap with invented consumption.
