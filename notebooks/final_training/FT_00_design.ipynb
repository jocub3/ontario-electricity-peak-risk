# %% [markdown]
# # FT 00 — Final Training Design
#
# Train deployable artifacts using all available history only after final holdout results are documented.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = PROJECT_ROOT / "configs" / "final_training.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/final_training.yaml')

# %% [markdown]
# This phase does not retune or reselect anything. It only fits the frozen configurations on all available historical data.
