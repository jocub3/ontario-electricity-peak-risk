# %% [markdown]
# # FT 01/03 — Train Final Model Artifacts
#
# Serialize the 24 Random Forest and 24 XGBoost horizon-specific pipelines.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = PROJECT_ROOT / "configs" / "final_training.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/final_training.yaml')

# %%
# Import function to run final training
from src.ontario_peak_risk.final_training.run_training import run_final_training

# %%
# Run final training
manifest = run_final_training(CONFIG_PATH)
# Out:
# [Final RF 1/24] saved
# [Final RF 2/24] saved
# [Final RF 3/24] saved
# [Final RF 4/24] saved
# [Final RF 5/24] saved
# [Final RF 6/24] saved
# [Final RF 7/24] saved
# [Final RF 8/24] saved
# [Final RF 9/24] saved
# [Final RF 10/24] saved
# [Final RF 11/24] saved
# [Final RF 12/24] saved
# [Final RF 13/24] saved
# [Final RF 14/24] saved
# [Final RF 15/24] saved
# [Final RF 16/24] saved
# [Final RF 17/24] saved
# [Final RF 18/24] saved
# [Final RF 19/24] saved
# [Final RF 20/24] saved
# [Final RF 21/24] saved
# [Final RF 22/24] saved
# [Final RF 23/24] saved
# [Final RF 24/24] saved
# [Final XGB 1/24] saved
# [Final XGB 2/24] saved
# [Final XGB 3/24] saved
# [Final XGB 4/24] saved
# [Final XGB 5/24] saved
# [Final XGB 6/24] saved
# [Final XGB 7/24] saved
# [Final XGB 8/24] saved
# [Final XGB 9/24] saved
# [Final XGB 10/24] saved
# [Final XGB 11/24] saved
# [Final XGB 12/24] saved
# [Final XGB 13/24] saved
# [Final XGB 14/24] saved
# [Final XGB 15/24] saved
# [Final XGB 16/24] saved
# ...

# %%
# Display manifest
manifest
# Out:
# {'status': 'FINAL_MODELS_TRAINED',
#  'rf_artifact_count': 24,
#  'xgb_artifact_count': 24,
#  'peak_threshold_table': 'peak_risk_xgboost/peak_thresholds.parquet',
#  'holdout_results_were_not_used_to_change_configuration': True}
