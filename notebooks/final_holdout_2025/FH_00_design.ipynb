# %% [markdown]
# # FH 00 — Final Holdout Design
#
# Review the one-time 2025 evaluation policy before opening the holdout.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = PROJECT_ROOT / "configs" / "final_holdout_2025.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/final_holdout_2025.yaml')

# %% [markdown]
# Frozen before 2025:
# - Random Forest hyperparameters and features
# - XGBoost hyperparameters and features
# - Peak definition P97.5 by FSA + season
# - XGBoost operational threshold 0.06
#
# After 2025 is evaluated, these choices must not be changed because of the test result.
