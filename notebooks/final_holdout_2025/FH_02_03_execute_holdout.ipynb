# %% [markdown]
# # FH 02/03 — Execute Frozen 2025 Holdout
#
# Train on the pre-2025 training window and evaluate both frozen models on 2025.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define config paths
PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "src").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
CONFIG_PATH = PROJECT_ROOT / "configs" / "final_holdout_2025.yaml"
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/DataLocal/ontario-electricity-peak-risk/configs/final_holdout_2025.yaml')

# %%
# Import functions to run holdout
from src.ontario_peak_risk.final_holdout.run_holdout import run_final_holdout

# %%
# Run final holdout
results = run_final_holdout(CONFIG_PATH)
# Out:
# [RF Holdout 1/24] completed
# [RF Holdout 2/24] completed
# [RF Holdout 3/24] completed
# [RF Holdout 4/24] completed
# [RF Holdout 5/24] completed
# [RF Holdout 6/24] completed
# [RF Holdout 7/24] completed
# [RF Holdout 8/24] completed
# [RF Holdout 9/24] completed
# [RF Holdout 10/24] completed
# [RF Holdout 11/24] completed
# [RF Holdout 12/24] completed
# [RF Holdout 13/24] completed
# [RF Holdout 14/24] completed
# [RF Holdout 15/24] completed
# [RF Holdout 16/24] completed
# [RF Holdout 17/24] completed
# [RF Holdout 18/24] completed
# [RF Holdout 19/24] completed
# [RF Holdout 20/24] completed
# [RF Holdout 21/24] completed
# [RF Holdout 22/24] completed
# [RF Holdout 23/24] completed
# [RF Holdout 24/24] completed
# [XGB Holdout 1/24] completed
# [XGB Holdout 2/24] completed
# [XGB Holdout 3/24] completed
# [XGB Holdout 4/24] completed
# [XGB Holdout 5/24] completed
# [XGB Holdout 6/24] completed
# [XGB Holdout 7/24] completed
# [XGB Holdout 8/24] completed
# ...

# %%
# Display Random Forest results
display(results["rf_global"])
# Out:
#                    model         mae        rmse      mape      wape  \
# 0  RandomForestRegressor  540.522948  927.028017  5.416811  5.593021
#
#         bias  n_observations
# 0 -53.182112         1257984

# %%
# Display XGBoos results
display(results["xgb_global"])
# Out:
#                model  operational_threshold  precision    recall        f1  \
# 0  XGBoostClassifier                   0.06   0.341029  0.930234  0.499089
#
#    balanced_accuracy    pr_auc   roc_auc  brier_score  true_negative  \
# 0           0.898304  0.711804  0.963583     0.042783        1014468
#
#    false_positive  false_negative  true_positive  actual_peak_rate_pct  \
# 0          156468            6073          80975              6.919643
#
#    predicted_peak_rate_pct  n_observations
# 0                18.874882         1257984
