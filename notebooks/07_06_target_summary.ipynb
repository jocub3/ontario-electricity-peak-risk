# %% [markdown]
# # 07.06 — Target Definition Summary
#
# Execute the complete Target Definition Phase workflow and review the final modeling handoff.

# %%
# Import libraries
from pathlib import Path
import sys

# %%
# Define the root directory of the project
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / 'configs' / 'target_definition.yaml'
CONFIG_PATH
# Out:
# WindowsPath('e:/jcuenca/OneDrive - GUSCanada/5toTerm/01_Capstone/Codigo/ontario-electricity-peak-risk/configs/target_definition.yaml')

# %%
# Import the run_target_definition function
from src.ontario_peak_risk.target_definition.run_target_definition import run_target_definition

# %%
# Run the target definition process and display the results
results = run_target_definition(CONFIG_PATH)
results.keys()
# Out:
# Target Definition Phase completed successfully.
# Rows in feature dataset: 262,944
# Complete 24-hour forecast origins: 262,800
# Outputs: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\data\processed\target_definition
# Reports: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\reports\target_definition
# Documentation: E:\jcuenca\OneDrive - GUSCanada\5toTerm\01_Capstone\Codigo\ontario-electricity-peak-risk\docs\target_definition
# dict_keys(['feature_dataset', 'forecast_matrix', 'complete_forecast_matrix', 'forecast_summary', 'peak_labels', 'peak_thresholds', 'peak_distributions', 'alignment_sample', 'forecast_validation', 'peak_validation'])

# %%
# Display the forecast summary from the results
results['forecast_summary']
# Out:
#         target  available_count  missing_count  coverage_pct
# 0   target_h01           262938              6     99.997718
# 1   target_h02           262932             12     99.995436
# 2   target_h03           262926             18     99.993154
# 3   target_h04           262920             24     99.990873
# 4   target_h05           262914             30     99.988591
# 5   target_h06           262908             36     99.986309
# 6   target_h07           262902             42     99.984027
# 7   target_h08           262896             48     99.981745
# 8   target_h09           262890             54     99.979463
# 9   target_h10           262884             60     99.977181
# 10  target_h11           262878             66     99.974900
# 11  target_h12           262872             72     99.972618
# 12  target_h13           262866             78     99.970336
# 13  target_h14           262860             84     99.968054
# ...

# %%
# Display the peak distributions from the results
results['peak_distributions']['overall']
# Out:
#    observations  peak_hours  peak_rate_pct
# 0        210384       13784       6.551829

# %%
# Display the forecast validation results from the results
results['forecast_validation']
# Out:
#                       check  violations status  \
# 0   target_origin_row_count           0   PASS
# 1    unique_forecast_origin           0   PASS
# 2             alignment_h01           0   PASS
# 3             alignment_h02           0   PASS
# 4             alignment_h03           0   PASS
# 5             alignment_h04           0   PASS
# 6             alignment_h05           0   PASS
# 7             alignment_h06           0   PASS
# 8             alignment_h07           0   PASS
# 9             alignment_h08           0   PASS
# 10            alignment_h09           0   PASS
# 11            alignment_h10           0   PASS
# 12            alignment_h11           0   PASS
# 13            alignment_h12           0   PASS
# 14            alignment_h13           0   PASS
# 15            alignment_h14           0   PASS
# 16            alignment_h15           0   PASS
# 17            alignment_h16           0   PASS
# 18            alignment_h17           0   PASS
# ...

# %%
# Display the peak validation results from the results
results['peak_validation']
# Out:
#                                      check  violations status  \
# 0                    unique_peak_label_key           0   PASS
# 1                        peak_label_binary           0   PASS
# 2  peak_threshold_availability_consistency           0   PASS
# 3    walk_forward_threshold_no_future_year           0   PASS
#
#                                          description
# 0  Diagnostic Peak labels must be unique by FSA +...
# 1  Peak-Risk labels must be binary when a thresho...
# 2  Available thresholds must produce a diagnostic...
# 3  Each diagnostic threshold must be fitted using...
